# %%
import pandas as pd
from keras import models
# Out:
# ---------------------------------------------------------------------------
# SymbolAlreadyExposedError                 Traceback (most recent call last)
# <ipython-input-1-cd22082601fe> in <module>
#       1 import pandas as pd
# ----> 2 from keras import models
#
# c:\Users\mutis\anaconda3\envs\learn-env\lib\site-packages\keras\__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# c:\Users\mutis\anaconda3\envs\learn-env\lib\site-packages\keras\__internal__\__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# c:\Users\mutis\anaconda3\envs\learn-env\lib\site-packages\keras\__internal__\backend\__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ...

# %%
df = pd.read_csv('featuure_engineered.csv') 
df.head()
# Out:
#    months_as_customer  age  policy_number policy_state policy_csl  \
# 0                 328   48         521585           OH    250/500
# 1                 228   42         342868           IN    250/500
# 2                 134   29         687698           OH    100/300
# 3                 256   41         227811           IL    250/500
# 4                 228   44         367455           IL   500/1000
#
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0               1000                1406.91               0       466132
# 1               2000                1197.22         5000000       468176
# 2               2000                1413.14         5000000       430632
# 3               2000                1415.74         6000000       608117
# 4               1000                1583.91         6000000       610706
#
#   insured_sex  ... policy_bind_date_year policy_bind_date_cosine_month  \
# ...
